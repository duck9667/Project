# %%
import pandas as pd
add = pd.read_csv('/Users/dreamus/Desktop/동작구_연령별_통계.csv')

# %%
id_vars = ['시도', '시군구', '행정동','latitude', 'longitude']

# %%
def melting(col):
    return pd.melt(col, id_vars=id_vars, var_name='sort', value_name='value')


df1 = melting(add)

# %%
df1.to_csv('동작구_연령별_통계_v1.csv',encoding='utf-8-sig',index=False)

# %% [markdown]
# ### <b> 동작구 1차 filter </b>

# %% [markdown]
# - index형 데이터 제거, binary class -> one-hot-encoding 변환

# %%
import pandas as pd
df = pd.read_csv('/Users/dreamus/Desktop/work/공모전/final.csv')
drop_table = ['province','city','dong','address','latitude','longitude']
read_df = df.drop(drop_table,axis=1)
read_df = pd.get_dummies(read_df)

# %% [markdown]
# - feature set을 클러스터링하기 위해 필드 scaling
# <br> -> scaler는 z-scale(StandardScaler) </br>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
new_data = scaler.fit_transform(read_df)
new_df = pd.DataFrame(new_data)
new_df.columns = read_df.columns

# %% [markdown]
# - 클러스터 개수를 결정하기 위해 elbow method
# <br> 비교 클러스터 개수 범위 : 1~10개 </br>

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot  as plt
plt.figure(figsize=(12, 6))

def elbow(X):
    sse = []

    for i in range(1,10):
        km = KMeans(n_clusters=i,algorithm='auto', random_state=42)
        km.fit(X)
        sse.append(km.inertia_)

    plt.plot(range(1,10), sse, marker='o')
    plt.xlabel('K')
    plt.ylabel('SSE')
    plt.show()

elbow(new_df)

# %% [markdown]
# -> SSE가 감소하는 <i><b>4</b></i> 를 클러스터 개수로 결정

# %% [markdown]
# <h4> <b> Modeling - 결정된 클러스터 개수로 클러스터링 진행 </b> </h4>

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot  as plt

k = 4

model = KMeans(n_clusters=k,algorithm='auto')
model.fit(new_df)
predict = pd.DataFrame(model.predict(new_df))
predict.columns=['predict']

# %%
from sklearn.decomposition import PCA
plt.figure(figsize=(12, 8))

pca = PCA(n_components=2)
X = pca.fit_transform(new_df)
y_pred = model.labels_
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap='rainbow')
plt.show()

# %%
merge_data = pd.merge(df,predict,left_index=True,right_index=True,how='outer')
one = merge_data[merge_data['predict']==0]
two = merge_data[merge_data['predict']==1]
three = merge_data[merge_data['predict']==2]
four = merge_data[merge_data['predict']==3]

# %%
merge_data.sort_values(by='predict')
# Out:
#    province city   dong        address   latitude   longitude    pop  \
# 0     서울특별시  동작구  노량진1동  서울시 동작구 노량진1동  37.512307  126.942016  32563
# 5     서울특별시  동작구   사당3동   서울시 동작구 사당3동  37.486625  126.972085  26034
# 8     서울특별시  동작구   상도1동   서울시 동작구 상도1동  37.503243  126.949750  48153
# 9     서울특별시  동작구   상도2동   서울시 동작구 상도2동  37.505467  126.942311  29270
# 10    서울특별시  동작구   상도3동   서울시 동작구 상도3동  37.499204  126.931342  26041
# 11    서울특별시  동작구   상도4동   서울시 동작구 상도4동  37.500559  126.937805  29893
# 12    서울특별시  동작구  신대방1동  서울시 동작구 신대방1동  37.488947  126.910048  26599
# 14    서울특별시  동작구    흑석동    서울시 동작구 흑석동  37.505775  126.966591  35551
# 4     서울특별시  동작구   사당2동   서울시 동작구 사당2동  37.488753  126.979253  28290
# 7     서울특별시  동작구   사당5동   서울시 동작구 사당5동  37.485625  126.967016  12886
# 13    서울특별시  동작구  신대방2동  서울시 동작구 신대방2동  37.498403  126.924526  20719
# 1     서울특별시  동작구  노량진2동  서울시 동작구 노량진2동  37.508506  126.937359  13789
# 3     서울특별시  동작구   사당1동   서울시 동작구 사당1동  37.483155  126.978672  24026
# 6     서울특별시  동작구   사당4동   서울시 동작구 사당4동  37.480959  126.971631  14921
# 2     서울특별시  동작구    대방동    서울시 동작구 대방동  37.508164  126.926344  40177
#
#     pop_per_hs highschool  sort_10_14  sort_15_19  ratio_10_14  ratio_15_19  \
# 0         2.13          n         933        1131     2.904913     3.521390
# 5         2.43          n         808         881     3.167261     3.453412
# 8         2.15          n        1569        1925     3.435817     4.215390
# 9         2.25          n         929        1059     3.250866     3.705777
# 10        2.15          n         731        1038     2.873428     4.080189
# 11        2.19          n         883        1128     3.012521     3.848385
# 12        2.41          n        1245        1372     5.260489     5.797101
# 14        2.29          n         993        1250     3.037905     3.824150
# 4         2.33          y         785         953     2.840190     3.448026
# 7         2.25          y         447         503     3.366978     3.788792
# 13        2.19          y         863         894     4.249557     4.402206
# 1         1.78          n         222         400     1.750375     3.153828
# 3         1.78          n         373         619     1.599623     2.654602
# 6         2.10          n         332         458     2.269310     3.130554
# 2         2.32          y        1964        2419     4.970516     6.122036
#
#     predict
# 0         0
# 5         0
# 8         0
# 9         0
# 10        0
# 11        0
# 12        0
# 14        0
# 4         1
# 7         1
# 13        1
# 1         2
# 3         2
# 6         2
# 2         3

# %% [markdown]
# -클러스터 1 : 대방동, 신대방1동</br>
# <br>- 클러스터 2 : 사당2동, 사당5동, 신대방2동</br>
# <br>- 클러스터 3 : 노량진1동, 사당3동, 상도1동,상도2동,상도3동, 상도4동,흑석동</br>
# <br>- 클러스터 4 : 노량진2동, 사당1동</br>

# %%
one.describe().iloc[1:5,2:8]
# Out:
#                pop  pop_per_hs   sort_10_14  sort_15_19  ratio_10_14  \
# mean  31763.000000     2.25000  1011.375000  1223.00000     3.367900
# std    7421.615284     0.11808   271.304751   318.77175     0.786903
# min   26034.000000     2.13000   731.000000   881.00000     2.873428
# 25%   26459.500000     2.15000   864.250000  1053.75000     2.985619
#
#       ratio_15_19
# mean     4.055724
# std      0.748890
# min      3.453412
# 25%      3.659680

# %% [markdown]
# 클러스터 1 특징 : 거주인구가 많고 10대 비율이 타 지역보다 많다.
# 이 중 <b>대방동</b>은 이미 고등학교가 4개 설립되어 있다.

# %%
two.describe().iloc[1:5,2:8]
# Out:
#                pop  pop_per_hs  sort_10_14  sort_15_19  ratio_10_14  \
# mean  20631.666667    2.256667  698.333333  783.333333     3.485575
# std    7702.371345    0.070238  221.127414  244.561512     0.712129
# min   12886.000000    2.190000  447.000000  503.000000     2.840190
# 25%   16802.500000    2.220000  616.000000  698.500000     3.103584
#
#       ratio_15_19
# mean     3.879675
# std      0.483539
# min      3.448026
# 25%      3.618409

# %% [markdown]
# 클러스터 2 특징 : 2번째로 10대 비율이 많고, 이미 모두 고등학교가 설립된 지역

# %%
three.describe().iloc[1:5,2:8]
# Out:
#                pop  pop_per_hs  sort_10_14  sort_15_19  ratio_10_14  \
# mean  17578.666667    1.886667  309.000000  492.333333     1.873102
# std    5612.168595    0.184752   78.083289  113.465119     0.351307
# min   13789.000000    1.780000  222.000000  400.000000     1.599623
# 25%   14355.000000    1.780000  277.000000  429.000000     1.674999
#
#       ratio_15_19
# mean     2.979661
# std      0.281750
# min      2.654602
# 25%      2.892578

# %% [markdown]
# 클러스터 3 특징 : 고등학교가 설립되어 있지 않으며, 2번째 클러스터와 10대 비율이 비슷함.
# <br> <b>흑석동이 포함되어 있음<b> </br>

# %%
four.describe().iloc[1:5,2:8]
# Out:
#           pop  pop_per_hs  sort_10_14  sort_15_19  ratio_10_14  ratio_15_19
# mean  40177.0        2.32      1964.0      2419.0     4.970516     6.122036
# std       NaN         NaN         NaN         NaN          NaN          NaN
# min   40177.0        2.32      1964.0      2419.0     4.970516     6.122036
# 25%   40177.0        2.32      1964.0      2419.0     4.970516     6.122036

# %% [markdown]
# 클러스터 4 특징 : 10대 비율 낮음, 가구원수 적음

# %% [markdown]
# 세대당 가구원수가 다른 지역에 비해 훨씬 적음 (1인가구 및 고시원 영향인듯.)
# <br> 가장 중요한 건 10대 비율이 낮다. </br>

# %%
merge_data_1 = merge_data[['dong','pop','pop_per_hs','sort_10_14','sort_15_19','ratio_10_14','ratio_15_19']]
merge_data_1.style.bar()
# Out:
# <style  type="text/css" >
#     #T_eac741b4_8509_11ea_a74e_acde48001122row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 55.8%, transparent 55.8%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 53.8%, transparent 53.8%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.8%, transparent 40.8%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.2%, transparent 36.2%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.7%, transparent 35.7%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.0%, transparent 25.0%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.6%, transparent 2.6%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row1_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row1_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row1_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.1%, transparent 4.1%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.4%, transparent 14.4%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 77.4%, transparent 77.4%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 83.1%, transparent 83.1%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 92.1%, transparent 92.1%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.6%, transparent 31.6%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row3_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.7%, transparent 8.7%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.8%, transparent 10.8%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row3_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row3_col6 {
#             width:  10em;
#              height:  80%;
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.7%, transparent 43.7%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 84.6%, transparent 84.6%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.3%, transparent 32.3%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.4%, transparent 27.4%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.9%, transparent 33.9%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.9%, transparent 22.9%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 37.3%, transparent 37.3%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.6%, transparent 33.6%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.8%, transparent 23.8%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 42.8%, transparent 42.8%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row5_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.0%, transparent 23.0%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.8%, transparent 5.8%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 49.2%, transparent 49.2%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.3%, transparent 6.3%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.9%, transparent 2.9%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row6_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.3%, transparent 18.3%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row6_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.7%, transparent 13.7%);
#         }    #T_eac741b4_8509_11ea_a74e_acde48001122row7_col1 {
#             width:  10em;
#              height:  80%;

# %% [markdown]
# <h3> 10-14비율 </h3>

# %%
import seaborn as sns

plt.figure(figsize=(12, 8))
g = sns.kdeplot(merge_data['ratio_10_14'][(merge_data['predict'] == 0) & (merge_data["ratio_10_14"].notnull())], color="Orange", shade = True)
g = sns.kdeplot(merge_data['ratio_10_14'][(merge_data['predict'] == 1) & (merge_data["ratio_10_14"].notnull())], color="Red", shade = True)
g = sns.kdeplot(merge_data['ratio_10_14'][(merge_data['predict'] == 2) & (merge_data["ratio_10_14"].notnull())], ax =g, color="Blue", shade= True)
g = sns.kdeplot(merge_data['ratio_10_14'][(merge_data['predict'] == 3) & (merge_data["ratio_10_14"].notnull())], ax =g, color="Green", shade= True)

g.set_xlabel("ratio_10_14")
g.set_ylabel("Frequency")
g = g.legend(["1","2","3","4"])
# Out:
# /Users/dreamus/anaconda3/envs/py3k/lib/python3.8/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# <h3> 15-19 비율 </h3>

# %%
import seaborn as sns

plt.figure(figsize=(12, 8))
g = sns.kdeplot(merge_data['ratio_15_19'][(merge_data['predict'] == 0) & (merge_data["ratio_15_19"].notnull())], color="Orange", shade = True)
g = sns.kdeplot(merge_data['ratio_15_19'][(merge_data['predict'] == 1) & (merge_data["ratio_15_19"].notnull())], color="Red", shade = True)
g = sns.kdeplot(merge_data['ratio_15_19'][(merge_data['predict'] == 2) & (merge_data["ratio_15_19"].notnull())], ax =g, color="Blue", shade= True)
g = sns.kdeplot(merge_data['ratio_15_19'][(merge_data['predict'] == 3) & (merge_data["ratio_15_19"].notnull())], ax =g, color="Green", shade= True)

g.set_xlabel("ratio_15_19")
g.set_ylabel("Frequency")
g = g.legend(["1","2","3","4"])
# Out:
# /Users/dreamus/anaconda3/envs/py3k/lib/python3.8/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 2번 클러스터는 이미 10대와 많은 고등학교가 설립된 지역이고, 4번은 10대 비중이 너무 적은 지역이기에 베재시키는 게 맞는 것 같음.
#
# -클러스터 1 : 신대방1동
# - 클러스터 3 : 노량진1동, 사당3동, 상도1동,상도2동,상도3동, 상도4동,흑석동
#
# <b> 그 중 클러스터 1의 대방동은 이미 고등학교가 4개나 설립이 되어있기에 제외시킴 </b>

# %% [markdown]
# <h3> mapping </h3>

# %%
from IPython.display import Image
display(Image("/Users/dreamus/Desktop/dongjak.png",width=850,height=650,unconfined=True))

# %%
import folium 
from folium import plugins

one_map = one[['latitude','longitude']]
m = folium.Map([37.498, 126.920], zoom_start=13)

plugins.MousePosition().add_to(m) 

plugins.MarkerCluster(one_map).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium 
from folium import plugins

two_map = two[['latitude','longitude']]
m = folium.Map([37.491, 126.950], zoom_start=13.5)

plugins.MousePosition().add_to(m) 

plugins.MarkerCluster(two_map).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium 
from folium import plugins

three_map = three[['latitude','longitude']]
m = folium.Map([37.495, 126.955], zoom_start=14)

plugins.MousePosition().add_to(m) 

plugins.MarkerCluster(three_map).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium 
from folium import plugins

four_map = four[['latitude','longitude']]
m = folium.Map([37.494, 126.955], zoom_start=13.5)

plugins.MousePosition().add_to(m) 

plugins.MarkerCluster(four_map).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
