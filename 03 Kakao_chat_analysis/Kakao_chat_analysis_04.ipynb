# %% [raw]
# # Data load

# %%
import re
import pandas as pd
import datetime as dt


def read_kko_msg(filename):
    with open(filename, encoding='utf-8') as f:
        msg_list = f.readlines()

    return msg_list


def apply_kko_regex(msg_list):
    kko_pattern = re.compile("\[([\S\s]+)\] \[(오전|오후) ([0-9:\s]+)\] ([^\n]+)")
    kko_date_pattern = re.compile("--------------- ([0-9]+년 [0-9]+월 [0-9]+일) ")

    emoji_pattern = re.compile("["u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               "]+", flags=re.UNICODE)

    kko_parse_result = list()
    cur_date = ""

    for msg in msg_list:
        # 날짜 부분인 경우
        if len(kko_date_pattern.findall(msg)) > 0:
            cur_date = dt.datetime.strptime(kko_date_pattern.findall(msg)[0], "%Y년 %m월 %d일")
            cur_date = cur_date.strftime("%Y-%m-%d")
        else:
            kko_pattern_result = kko_pattern.findall(msg)
            if len(kko_pattern_result) > 0:
                tokens = list(kko_pattern_result[0])
                # 이모지 데이터 삭제
                tokens[-1] = re.sub(emoji_pattern, "", tokens[-1])
                tokens.insert(0, cur_date)
                kko_parse_result.append(tokens)

    kko_parse_result = pd.DataFrame(kko_parse_result, columns=["Date", "Speaker", "timetype", "time", "contents"])
    kko_parse_result.to_csv("kko_regex.csv", index=False)

    return kko_parse_result


if __name__ == '__main__':
    msg_list = read_kko_msg("C://Users//user//Github/Project_Kakao chat/카톡대화.txt")
    apply_kko_regex(msg_list)

# %%
df = pd.read_csv("C://Users//user//Github/Project_Kakao chat/kko_regex.csv")

# %%
df.head()
# Out:
#          Date Speaker timetype  time     contents
# 0  2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음
# 1  2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네
# 2  2017-01-19     김재민       오전  2:19            오
# 3  2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음
# 4  2017-01-19     김재민       오전  2:19          ㅋㅋㅋ

# %% [markdown]
# # Data Preparation

# %%
df.Date = pd.to_datetime(df.Date)

# %%
df.dtypes
# Out:
# Date        datetime64[ns]
# Speaker             object
# timetype            object
# time                object
# contents            object
# dtype: object

# %%
df["year"] = df['Date'].dt.strftime('%Y')
df["month"] = df['Date'].dt.strftime('%m')
df["day"] = df['Date'].dt.strftime('%d')
df["weekday"] = df['Date'].dt.weekday_name

df["24time"] = df["timetype"] + " " + df["time"]
df["24time"] = df["24time"].map(lambda x : x.replace("오전","AM"))
df["24time"] = df["24time"].map(lambda x : x.replace("오후","PM"))

# %%
temp = []
transform_time = []
for i in range(len(df)) :
    time = df["24time"][i]
    temp.append(dt.datetime.strptime(time,"%p %I:%M"))
    transform_time.append(temp[i].time())

df["24time"] = transform_time

# %%
df.head()
# Out:
#         Date Speaker timetype  time     contents  year month day   weekday  \
# 0 2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음  2017    01  19  Thursday
# 1 2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네  2017    01  19  Thursday
# 2 2017-01-19     김재민       오전  2:19            오  2017    01  19  Thursday
# 3 2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음  2017    01  19  Thursday
# 4 2017-01-19     김재민       오전  2:19          ㅋㅋㅋ  2017    01  19  Thursday
#
#      24time
# 0  02:16:00
# 1  02:16:00
# 2  02:19:00
# 3  02:19:00
# 4  02:19:00

# %%
df.isnull().sum()
# Out:
# Date         0
# Speaker      0
# timetype     0
# time         0
# contents    46
# year         0
# month        0
# day          0
# weekday      0
# 24time       0
# dtype: int64

# %%
df = df.fillna('null')

# %%
df.isnull().sum()
# Out:
# Date        0
# Speaker     0
# timetype    0
# time        0
# contents    0
# year        0
# month       0
# day         0
# weekday     0
# 24time      0
# dtype: int64

# %%
title_len = []

for i in range(len(df)):
    ttl = len(df['contents'][i])
    title_len.append(ttl)

df['length'] = title_len
df.head()
# Out:
#         Date Speaker timetype  time     contents  year month day   weekday  \
# 0 2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음  2017    01  19  Thursday
# 1 2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네  2017    01  19  Thursday
# 2 2017-01-19     김재민       오전  2:19            오  2017    01  19  Thursday
# 3 2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음  2017    01  19  Thursday
# 4 2017-01-19     김재민       오전  2:19          ㅋㅋㅋ  2017    01  19  Thursday
#
#      24time  length
# 0  02:16:00      10
# 1  02:16:00      11
# 2  02:19:00       1
# 3  02:19:00      11
# 4  02:19:00       3

# %%
df.dtypes
# Out:
# Date        datetime64[ns]
# Speaker             object
# timetype            object
# time                object
# contents            object
# year                object
# month               object
# day                 object
# weekday             object
# 24time              object
# length               int64
# dtype: object

# %%
# 시간 분 설정
str_time = []
hh = []
mm = []
# bin_size = 15

for i in range(len(df)) :
    a = str(df["24time"][i])
    str_time.append(a.replace(":"," ").split(" "))
    
    h = str_time[i][0]
    m = str_time[i][1] ## //bin_size*bin_size # 두번 나누면 몫
    
    hh.append(h)
    mm.append(m)

df["hh"] = hh
df["mm"] = mm

# %time
# Out:
# Wall time: 0 ns

# %%
df.head()
# Out:
#         Date Speaker timetype  time     contents  year month day   weekday  \
# 0 2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음  2017    01  19  Thursday
# 1 2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네  2017    01  19  Thursday
# 2 2017-01-19     김재민       오전  2:19            오  2017    01  19  Thursday
# 3 2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음  2017    01  19  Thursday
# 4 2017-01-19     김재민       오전  2:19          ㅋㅋㅋ  2017    01  19  Thursday
#
#      24time  length  hh  mm
# 0  02:16:00      10  02  16
# 1  02:16:00      11  02  16
# 2  02:19:00       1  02  19
# 3  02:19:00      11  02  19
# 4  02:19:00       3  02  19

# %%
quarter = []
# 계절 설정

for i in range(len(df)) :
    a = int(df["month"][i])
    if a >= 1 and a <= 3 :
        quarter.append("1q")
    if a >= 4 and a <= 6 :
        quarter.append("2q")
    if a >= 7 and a <= 9 :
        quarter.append("3q")
    if a >= 10 and a <= 12 :
        quarter.append("4q")

df["quarter"] = quarter

# %%
df.head()
# Out:
#         Date Speaker timetype  time     contents  year month day   weekday  \
# 0 2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음  2017    01  19  Thursday
# 1 2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네  2017    01  19  Thursday
# 2 2017-01-19     김재민       오전  2:19            오  2017    01  19  Thursday
# 3 2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음  2017    01  19  Thursday
# 4 2017-01-19     김재민       오전  2:19          ㅋㅋㅋ  2017    01  19  Thursday
#
#      24time  length  hh  mm quarter
# 0  02:16:00      10  02  16      1q
# 1  02:16:00      11  02  16      1q
# 2  02:19:00       1  02  19      1q
# 3  02:19:00      11  02  19      1q
# 4  02:19:00       3  02  19      1q

# %% [markdown]
# # Visualization

# %%
# 그래프 모듈 설치
import seaborn as sns

# 그래프 삽입 모듈 및 그래프 내 한글 폰트 삽입 코드
import matplotlib.pyplot as plt
plt.rc('font', family='NanumGothic')
print(plt.rcParams['font.family'])

fig, ax = plt.subplots(figsize=(10,5))

g = sns.kdeplot(df['hh'][(df['Speaker'] == '김성화') & (df["hh"].notnull())], color="Black", shade = True)
g = sns.kdeplot(df['hh'][(df['Speaker'] == '곽종현🎗') & (df["hh"].notnull())], ax =g, color="Blue", shade= True)
g = sns.kdeplot(df['hh'][(df['Speaker'] == '김신기') & (df["hh"].notnull())], ax =g, color="Gray", shade= True)
g = sns.kdeplot(df['hh'][(df['Speaker'] == '김재민') & (df["hh"].notnull())], ax =g, color="Green", shade= True)

g.set_xlabel("viewCount")
g.set_ylabel("Frequency")
plt.title("시간별 채팅 비율")
g = g.legend(["김성화","곽종현","김신기","김재민"])
# Out:
# ['NanumGothic']

# %%
fig, ax = plt.subplots(figsize=(10,5))

g = sns.kdeplot(df['month'][(df['Speaker'] == '김성화') & (df["month"].notnull())], color="Black", shade = True)
g = sns.kdeplot(df['month'][(df['Speaker'] == '곽종현🎗') & (df["month"].notnull())], ax =g, color="Blue", shade= True)
g = sns.kdeplot(df['month'][(df['Speaker'] == '김신기') & (df["month"].notnull())], ax =g, color="Gray", shade= True)
g = sns.kdeplot(df['month'][(df['Speaker'] == '김재민') & (df["month"].notnull())], ax =g, color="Green", shade= True)

g.set_xlabel("viewCount")
g.set_ylabel("Frequency")
plt.title("월별 채팅 비율")
g = g.legend(["김성화","곽종현","김신기","김재민"],loc="best")

# %%
from collections import Counter
temp = Counter(df["24time"]).most_common(10000)
stime = sorted(temp, key = lambda x : x[0])
t, c = zip(*stime)

# %%
from matplotlib.dates import DateFormatter
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,5))
plt.plot_date(t,c,fmt='-') # fmt는 실선인지 점선인지 모양 구분
ax.xaxis.set_tick_params(labelsize = 10) #rotation = 30

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = '00:00'
labels[2] = '05:33'
labels[3] = '11:06'
labels[4] = '16:40'
labels[5] = '22:13'

ax.set_xticklabels(labels)

plt.show()

# %%
df.head()
# Out:
#         Date Speaker timetype  time     contents  year month day   weekday  \
# 0 2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음  2017    01  19  Thursday
# 1 2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네  2017    01  19  Thursday
# 2 2017-01-19     김재민       오전  2:19            오  2017    01  19  Thursday
# 3 2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음  2017    01  19  Thursday
# 4 2017-01-19     김재민       오전  2:19          ㅋㅋㅋ  2017    01  19  Thursday
#
#      24time  length  hh  mm quarter
# 0  02:16:00      10  02  16      1q
# 1  02:16:00      11  02  16      1q
# 2  02:19:00       1  02  19      1q
# 3  02:19:00      11  02  19      1q
# 4  02:19:00       3  02  19      1q

# %%
df.groupby('Date').count()['24time'].plot(kind='line', figsize=(15,5))
plt.title('일일 카톡 건수')
plt.xticks(rotation = 0)
plt.show()

# %%
# 가장 많은 카톡을 한 상위 5일
df.groupby('Date').count()['24time']

# %%
df["Speaker"][df["Speaker"] == "곽종현🎗] [오후 7:49] [김성화" ] = "김성화"
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df["Speaker"][df["Speaker"] == "곽종현🎗] [오전 11:18] [김신기" ] = "김신기"
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df["Speaker"].value_counts()
# Out:
# 김재민     56860
# 김성화     37108
# 곽종현🎗    31925
# 김신기     23315
# Name: Speaker, dtype: int64

# %%
count_df = df.groupby('Speaker').count()['contents']

# %%
fig, ax = plt.subplots(figsize=(10,5))

count_df.plot(kind='bar')
plt.title('보낸 카톡 수')

ax.xaxis.set_tick_params(labelsize = 10, rotation=360) 

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[0] = '곽종현'
labels[1] = '김성화'
labels[2] = '김신기'
labels[3] = '김재민'

ax.set_xticklabels(labels)


plt.show()

# %%
df.head()
# Out:
#         Date Speaker timetype  time     contents  year month day   weekday  \
# 0 2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음  2017    01  19  Thursday
# 1 2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네  2017    01  19  Thursday
# 2 2017-01-19     김재민       오전  2:19            오  2017    01  19  Thursday
# 3 2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음  2017    01  19  Thursday
# 4 2017-01-19     김재민       오전  2:19          ㅋㅋㅋ  2017    01  19  Thursday
#
#      24time  length  hh  mm quarter
# 0  02:16:00      10  02  16      1q
# 1  02:16:00      11  02  16      1q
# 2  02:19:00       1  02  19      1q
# 3  02:19:00      11  02  19      1q
# 4  02:19:00       3  02  19      1q

# %%
date = []
time = []
for i in range(len(df)) :
    dd = str(df["Date"][i]).split(" 00:")[0]
    tt= str(df["24time"][i]).split(":00")[0]
    
    date.append(dd)
    time.append(tt)

# %%
d = pd.DataFrame(date)
t = pd.DataFrame(time)

# %%
df["Datetime"] = d + " " + t

# %%
df.head()
# Out:
#         Date Speaker timetype  time     contents  year month day   weekday  \
# 0 2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음  2017    01  19  Thursday
# 1 2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네  2017    01  19  Thursday
# 2 2017-01-19     김재민       오전  2:19            오  2017    01  19  Thursday
# 3 2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음  2017    01  19  Thursday
# 4 2017-01-19     김재민       오전  2:19          ㅋㅋㅋ  2017    01  19  Thursday
#
#      24time  length  hh  mm quarter          Datetime
# 0  02:16:00      10  02  16      1q  2017-01-19 02:16
# 1  02:16:00      11  02  16      1q  2017-01-19 02:16
# 2  02:19:00       1  02  19      1q  2017-01-19 02:19
# 3  02:19:00      11  02  19      1q  2017-01-19 02:19
# 4  02:19:00       3  02  19      1q  2017-01-19 02:19

# %%
df.Datetime = pd.to_datetime(df.Datetime)

# %%
df['delta'] = (df['Datetime'].shift(-1)-df['Datetime']).fillna(0)
df['is_indifferent'] = ((df['Speaker'] != df['Speaker'].shift(-1)) & ((df['delta'].dt.seconds//60 >= 10)&(df['delta'].dt.seconds//60 <= 30)))

# %%
df.head()
# Out:
#         Date Speaker timetype  time     contents  year month day   weekday  \
# 0 2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음  2017    01  19  Thursday
# 1 2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네  2017    01  19  Thursday
# 2 2017-01-19     김재민       오전  2:19            오  2017    01  19  Thursday
# 3 2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음  2017    01  19  Thursday
# 4 2017-01-19     김재민       오전  2:19          ㅋㅋㅋ  2017    01  19  Thursday
#
#      24time  length  hh  mm quarter            Datetime    delta  \
# 0  02:16:00      10  02  16      1q 2017-01-19 02:16:00 00:00:00
# 1  02:16:00      11  02  16      1q 2017-01-19 02:16:00 00:03:00
# 2  02:19:00       1  02  19      1q 2017-01-19 02:19:00 00:00:00
# 3  02:19:00      11  02  19      1q 2017-01-19 02:19:00 00:00:00
# 4  02:19:00       3  02  19      1q 2017-01-19 02:19:00 00:02:00
#
#    is_indifferent
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False

# %%
df["is_indifferent"].value_counts()
# Out:
# False    145028
# True       4180
# Name: is_indifferent, dtype: int64

# %%
df[df['is_indifferent']==True].groupby('Speaker').count()['contents']
# Out:
# Speaker
# 곽종현🎗     745
# 김성화     1168
# 김신기      911
# 김재민     1356
# Name: contents, dtype: int64

# %%
ice_age = pd.DataFrame(df[df['is_indifferent']==True].groupby('Speaker').count()['contents'])
ice_age.index.name = ""
ice_age.columns.name = ''

# %%
ice_age
# Out:
#       contents
#
# 곽종현🎗       745
# 김성화       1168
# 김신기        911
# 김재민       1356

# %%
ice_age.plot(kind='bar')
plt.title('대화를 얼어붙게 만든 횟수')
plt.tick_params(rotation=360)
plt.show()

# %%
# 가장 영양가 있는 대화를 하는 사람 - 대화를 얼어붙게 만든 비율 / 전체 카톡 중 채팅 비율
ice_age
# Out:
#       contents
#
# 곽종현🎗       745
# 김성화       1168
# 김신기        911
# 김재민       1356

# %%
ice_rate_sh = ice_age["contents"]["김성화"]/ice_age["contents"].sum()
ice_rate_jh = ice_age["contents"]["곽종현🎗"]/ice_age["contents"].sum()
ice_rate_sg = ice_age["contents"]["김신기"]/ice_age["contents"].sum()
ice_rate_jm = ice_age["contents"]["김재민"]/ice_age["contents"].sum()

# %%
count_df = pd.DataFrame(count_df)
count_df.index.name = ""
count_df.columns.name = ''
count_df
# Out:
#       contents
#
# 곽종현🎗     31925
# 김성화      37108
# 김신기      23315
# 김재민      56860

# %%
chat_rate_sh = count_df["contents"]["김성화"]/count_df["contents"].sum()
chat_rate_jh = count_df["contents"]["곽종현🎗"]/count_df["contents"].sum()
chat_rate_sg = count_df["contents"]["김신기"]/count_df["contents"].sum()
chat_rate_jm = count_df["contents"]["김재민"]/count_df["contents"].sum()

# %%
# ice_rate
ice_rate_SH = round(ice_rate_sh/chat_rate_sh,2)*100
ice_rate_JH = round(ice_rate_jh/chat_rate_jh,2)*100
ice_rate_SG = round(ice_rate_sg/chat_rate_sg,2)*100
ice_rate_JM = round(ice_rate_jm/chat_rate_jm,2)*100

# %%
ice_rate = pd.DataFrame(data=[ice_rate_SH,ice_rate_JH,ice_rate_SG,ice_rate_JM], index=["SH","JH","SG","JM"], columns=['ice_age_index'])
display(pd.DataFrame(ice_rate))
# Out:
#     ice_age_index
# SH          112.0
# JH           83.0
# SG          139.0
# JM           85.0

# %%
ice_rate.plot(kind='bar', figsize=(12,6))
plt.title("Ice age index")
plt.xticks(rotation=360,fontsize = 12)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)

# %%
# 19년 6월 부터 나누기 라이프스타일 변화
df1 = df[:117423]
len(df1)
# Out:
# 117423

# %%
df2 = df[117423:149206]
len(df2)
# Out:
# 31783

# %%
# 일별 대화량
Daliy_chat_df1 = len(df1) / len(df1["Date"].drop_duplicates())
Daliy_chat_df2 = len(df2) / len(df2["Date"].drop_duplicates())

print("라이프스타일 변화 전 : 일별평균", round(Daliy_chat_df1,1),"개", 
      "\n라이프스타일 변화 후 : 일별평균", round(Daliy_chat_df2,1), "개")
# Out:
# 라이프스타일 변화 전 : 일별평균 167.7 개
# 라이프스타일 변화 후 : 일별평균 130.3 개

# %%
df1.groupby('Speaker').count()['contents']
# Out:
# Speaker
# 곽종현🎗    23422
# 김성화     30771
# 김신기     19093
# 김재민     44137
# Name: contents, dtype: int64

# %%
total_before = df1.groupby('Speaker').count()['contents'].sum()
chat_before = pd.DataFrame(df1.groupby('Speaker').count()['contents'])
chat_before
# Out:
#          contents
# Speaker
# 곽종현🎗        23422
# 김성화         30771
# 김신기         19093
# 김재민         44137

# %%
before_sh = chat_before[chat_before.index == "김성화"]["contents"][0]
before_jh = chat_before[chat_before.index == "곽종현🎗"]["contents"][0]
before_sg = chat_before[chat_before.index == "김신기"]["contents"][0]
before_jm = chat_before[chat_before.index == "김재민"]["contents"][0]

before = [before_sh,before_jh,before_sg,before_jm]
before_name = ["김성화","곽종현","김신기","김재민"]

import numpy as np
np.array(before)
np.array(before_name)
# Out:
# array(['김성화', '곽종현', '김신기', '김재민'], dtype='<U3')

# %%
plt.figure(figsize=(6,4)) 
plt.title("라이프스타일 변화 전 대화 비중") 

plt.bar(np.array(before_name), np.array(before)/total_before, color='Blue')
# Out:
# <BarContainer object of 4 artists>

# %%
df2.groupby('Speaker').count()['contents']
# Out:
# Speaker
# 곽종현🎗     8503
# 김성화      6335
# 김신기      4222
# 김재민     12723
# Name: contents, dtype: int64

# %%
total_after = df2.groupby('Speaker').count()['contents'].sum()
chat_after = pd.DataFrame(df2.groupby('Speaker').count()['contents'])
chat_after
# Out:
#          contents
# Speaker
# 곽종현🎗         8503
# 김성화          6335
# 김신기          4222
# 김재민         12723

# %%
after_sh = chat_after[chat_after.index == "김성화"]["contents"][0]
after_jh = chat_after[chat_after.index == "곽종현🎗"]["contents"][0]
after_sg = chat_after[chat_after.index == "김신기"]["contents"][0]
after_jm = chat_after[chat_after.index == "김재민"]["contents"][0]

after = [after_sh, after_jh, after_sg, after_jm]
after_name = ["김성화","곽종현","김신기","김재민"]

import numpy as np
np.array(after)
np.array(after_name)
# Out:
# array(['김성화', '곽종현', '김신기', '김재민'], dtype='<U3')

# %%
plt.figure(figsize=(6,4)) 
plt.title("라이프스타일 변화 후 대화 비중") 

plt.bar(np.array(after_name), np.array(after)/total_after, color='Blue')
# Out:
# <BarContainer object of 4 artists>

# %%
# 평균 대화 길이 흡사 설명층
df.groupby("Speaker").sum()["length"]/df1.groupby("Speaker").count()["length"]
# Out:
# Speaker
# 곽종현🎗    10.575357
# 김성화     11.067986
# 김신기     11.962552
# 김재민      9.270703
# Name: length, dtype: float64

# %%
long_tongue = pd.DataFrame([10.6, 11.1, 12, 9.3],["곽종현", "김성화", "김신기", "김재민"],columns=["length"])

# %%
long_tongue
# Out:
#      length
# 곽종현    10.6
# 김성화    11.1
# 김신기    12.0
# 김재민     9.3

# %%
plt.figure(figsize=(12,4))
df.boxplot(column="length")

# %%
def removeOutliers(x, column):
    # Q1, Q3구하기
    q1 = x[column].quantile(0.25)
    q3 = x[column].quantile(0.75)
    
    # 1.5 * IQR(Q3 - Q1)
    iqt = 1.5 * (q3 - q1)
    
    # 원래 데이터 복제
    y = x
    
    # 이상치를 NA로 변환
    outlier = y["length"][(df["length"] > (q3 + iqt)) | (df["length"] < (q1 - iqt))]
    
    # y 반환
    return(outlier)

# %%
outlier_index = removeOutliers(df,"length").index

# %%
outlier = df.loc[outlier_index]

# %%
outlier.head()
# Out:
#           Date Speaker timetype   time  \
# 12  2017-01-19     김성화       오전   2:28
# 23  2017-01-19     김신기       오전  11:28
# 30  2017-01-19     김신기       오후   2:25
# 34  2017-01-19     김신기       오후   2:33
# 275 2017-01-21    곽종현🎗       오전  10:26
#
#                                               contents  year month day  \
# 12                      ㅋㅋㅋ그런애들 아빠가 콤마 틀라이언트 계약해주실수도있다  2017    01  19
# 23                          재민아 토트넘 경기 어떤 사이트 통해서 예매햇냐  2017    01  19
# 30                      유럽축구 예매 좋은 사이트 혹시 아나해서 물어보려고햇지  2017    01  19
# 34                          통합적으로 관리하는 사이트 혹시 아나해서 그랫징  2017    01  19
# 275  솔직히 너도나도 갔다고 생각했는데 막상 간다는건 힘들고 간애들 얘기만 들어서 그렇지...  2017    01  21
#
#       weekday    24time  length  hh  mm quarter            Datetime    delta  \
# 12   Thursday  02:28:00      30  02  28      1q 2017-01-19 02:28:00 00:01:00
# 23   Thursday  11:28:00      26  11  28      1q 2017-01-19 11:28:00 01:45:00
# 30   Thursday  14:25:00      30  14  25      1q 2017-01-19 14:25:00 00:00:00
# 34   Thursday  14:33:00      26  14  33      1q 2017-01-19 14:33:00 00:00:00
# 275  Saturday  10:26:00      61  10  26      1q 2017-01-21 10:26:00 00:02:00
#
#      is_indifferent
# 12            False
# 23            False
# 30            False
# 34            False
# 275           False

# %%
outlier.groupby("Speaker").count()["contents"]
# Out:
# Speaker
# 곽종현🎗    1058
# 김성화     1230
# 김신기     1030
# 김재민     1100
# Name: contents, dtype: int64

# %%
outlier.groupby("Speaker").sum()["length"]
# Out:
# Speaker
# 곽종현🎗    44185
# 김성화     43207
# 김신기     38971
# 김재민     47635
# Name: length, dtype: int64

# %%
outlier.groupby("Speaker").sum()["length"] / outlier.groupby("Speaker").count()["contents"]
# Out:
# Speaker
# 곽종현🎗    41.762760
# 김성화     35.127642
# 김신기     37.835922
# 김재민     43.304545
# dtype: float64

# %% [markdown]
# # Topic modeling

# %%
# 데이터 전처리
def preprocessing(text):
    # 개행문자 제거
    text = re.sub('\\\\n', ' ', text)
    # 특수문자,자음 제거
    text = re.sub('[.,;:\)*?!~`’^\-_+<>@\#$%&=#}※ㄱㄴㄷㄹㅁㅂㅅㅇㅈㅊㅋㅌㅍㅎㅠㅜ]', '', text)
    # 중복 생성 공백값
    text = re.sub(' +', ' ', text)
    return text


# 불용어 제거
def remove_stopwords(text):
    tokens = text.split(' ')
    stops = ['ㅎㅎㅎ','ㅎㅎ','ㅋㅋ','ㅋ','ㅎㅎ','ㅎ','ㅋㅋㅋ','ㅋㅋ','ㅠㅠㅠㅠ','ㅠㅠ',"신기","성화",'재민','종현'
            "그냥","거기","지금","이제","우리","일단","한번","나도","하는","그게","약간","그거","해서","재미","뭔가","이모티콘"
            "존나", "누가", "하기", "하는데", "거의", "할게", "이번", "이건", "사실", "정도", "갑자기", "혹시", "보고","하노"]
    meaningful_words = [w for w in tokens if not w in stops]
    return ' '.join(meaningful_words)

# %%
df['new'] = df['contents'].apply(preprocessing)
df['nnew'] = df['new'].apply(remove_stopwords)

# %%
df.head()
# Out:
#         Date Speaker timetype  time     contents  year month day   weekday  \
# 0 2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음  2017    01  19  Thursday
# 1 2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네  2017    01  19  Thursday
# 2 2017-01-19     김재민       오전  2:19            오  2017    01  19  Thursday
# 3 2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음  2017    01  19  Thursday
# 4 2017-01-19     김재민       오전  2:19          ㅋㅋㅋ  2017    01  19  Thursday
#
#      24time  length  hh  mm quarter            Datetime    delta  \
# 0  02:16:00      10  02  16      1q 2017-01-19 02:16:00 00:00:00
# 1  02:16:00      11  02  16      1q 2017-01-19 02:16:00 00:03:00
# 2  02:19:00       1  02  19      1q 2017-01-19 02:19:00 00:00:00
# 3  02:19:00      11  02  19      1q 2017-01-19 02:19:00 00:00:00
# 4  02:19:00       3  02  19      1q 2017-01-19 02:19:00 00:02:00
#
#    is_indifferent          new         nnew
# 0           False   오 팁 이만냥 받음   오 팁 이만냥 받음
# 1           False  재민 그동네 좀 좋네     그동네 좀 좋네
# 2           False            오            오
# 3           False  난 카지노 3만원잃음  난 카지노 3만원잃음
# 4           False

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\programdata\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: JPype1>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from konlpy) (0.7.0)
# Requirement already satisfied: beautifulsoup4==4.6.0 in c:\programdata\anaconda3\lib\site-packages (from konlpy) (4.6.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\programdata\anaconda3\lib\site-packages (from konlpy) (4.2.5)
# Requirement already satisfied: tweepy>=3.7.0 in c:\programdata\anaconda3\lib\site-packages (from konlpy) (3.8.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python37\site-packages (from konlpy) (0.4.1)
# Requirement already satisfied: numpy>=1.6 in c:\programdata\anaconda3\lib\site-packages (from konlpy) (1.18.1)
# Requirement already satisfied: requests>=2.11.1 in c:\programdata\anaconda3\lib\site-packages (from tweepy>=3.7.0->konlpy) (2.21.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\user\appdata\roaming\python\python37\site-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: PySocks>=1.5.7 in c:\programdata\anaconda3\lib\site-packages (from tweepy>=3.7.0->konlpy) (1.6.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2018.11.29)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)

# %%
# from konlpy.tag import Mecab
from konlpy.tag import Okt
import time

# %%
start = time.time()
okt = Okt()

nouns = []
morphs = []
pos = []

for i in range(len(df)):
    no = okt.nouns(str(df['nnew'][i]))
    mo = okt.morphs(str(df['nnew'][i]))
    po = okt.pos(str(df['nnew'][i]))
    nouns.append(no)
    morphs.append(mo)
    pos.append(po)

df['nouns'] = nouns
df['morphs'] = morphs
df['pos'] = pos

# %time
# Out:
# Wall time: 0 ns

# %%
df.head()
# Out:
#         Date Speaker timetype  time     contents  year month day   weekday  \
# 0 2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음  2017    01  19  Thursday
# 1 2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네  2017    01  19  Thursday
# 2 2017-01-19     김재민       오전  2:19            오  2017    01  19  Thursday
# 3 2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음  2017    01  19  Thursday
# 4 2017-01-19     김재민       오전  2:19          ㅋㅋㅋ  2017    01  19  Thursday
#
#      24time                        ...                          mm quarter  \
# 0  02:16:00                        ...                          16      1q
# 1  02:16:00                        ...                          16      1q
# 2  02:19:00                        ...                          19      1q
# 3  02:19:00                        ...                          19      1q
# 4  02:19:00                        ...                          19      1q
#
#              Datetime    delta is_indifferent          new         nnew  \
# 0 2017-01-19 02:16:00 00:00:00          False   오 팁 이만냥 받음   오 팁 이만냥 받음
# 1 2017-01-19 02:16:00 00:03:00          False  재민 그동네 좀 좋네     그동네 좀 좋네
# 2 2017-01-19 02:19:00 00:00:00          False            오            오
# 3 2017-01-19 02:19:00 00:00:00          False  난 카지노 3만원잃음  난 카지노 3만원잃음
# 4 2017-01-19 02:19:00 00:02:00          False
#
#         nouns             morphs  \
# 0  [오, 팁, 이만]  [오, 팁, 이만, 냥, 받음]
# 1     [동네, 좀]     [그, 동네, 좀, 좋네]
# 2         [오]                [오]
# 3    [난, 카지노]  [난, 카지노, 3만원, 잃음]
# 4          []                 []
#
#                                                  pos
# 0  [(오, Noun), (팁, Noun), (이만, Noun), (냥, Josa), ...
# 1  [(그, Determiner), (동네, Noun), (좀, Noun), (좋네, ...
# 2                                        [(오, Noun)]
# 3  [(난, Noun), (카지노, Noun), (3만원, Number), (잃음, F...
# 4                                                 []
#
# [5 rows x 22 columns]

# %%
verbs1 = df['pos']
dict_verb = []

for i in range(len(verbs1)):
    vb = dict(verbs1[i])
    dict_verb.append(vb)

df['dic_verb'] = dict_verb
df
# Out:
#              Date Speaker timetype   time                        contents  \
# 0      2017-01-19     김성화       오전   2:16                      오 팁 이만냥 받음
# 1      2017-01-19     김성화       오전   2:16                     재민 그동네 좀 좋네
# 2      2017-01-19     김재민       오전   2:19                               오
# 3      2017-01-19     김재민       오전   2:19                     난 카지노 3만원잃음
# 4      2017-01-19     김재민       오전   2:19                             ㅋㅋㅋ
# 5      2017-01-19     김성화       오전   2:21                            ㅋㅋ븅신
# 6      2017-01-19     김재민       오전   2:21                     ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 7      2017-01-19     김재민       오전   2:21                  여기 한심하게돈많은놈들많더
# 8      2017-01-19     김재민       오전   2:21                             개부럽
# 9      2017-01-19     김성화       오전   2:22                 ㅋㅋㅋ그새끼들 연락처받아놔라
# 10     2017-01-19     김재민       오전   2:26                           ㅋㅋㅋㅋㅋ
# 11     2017-01-19     김재민       오전   2:26                       근데좀무섭게생겻다
# 12     2017-01-19     김성화       오전   2:28  ㅋㅋㅋ그런애들 아빠가 콤마 틀라이언트 계약해주실수도있다
# 13     2017-01-19     김재민       오전   2:29                               오
# 14     2017-01-19     김재민       오전   2:29                          상하이 선화
# 15     2017-01-19     김성화       오전   2:35                        ㅣ번 여름방학땐
# 16     2017-01-19     김성화       오전   2:35          콤마 팀들 ㅗㅇ모전이고 나발이고 집어치고
# 17     2017-01-19     김성화       오전   2:35                        중국어공부시켜라
# 18     2017-01-19     김재민       오전   2:36                      ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 19     2017-01-19     김재민       오전   2:36                            해외진출
# 20     2017-01-19     김성화       오전   2:37                    아 알바 마치고싶다..
# 21     2017-01-19     김재민       오전   2:38                             마쳐라
# 22     2017-01-19     김성화       오전   2:40                          피고내피고내
# 23     2017-01-19     김신기       오전  11:28      재민아 토트넘 경기 어떤 사이트 통해서 예매햇냐
# 24     2017-01-19     김성화       오후   1:13                              쿠팡
# 25     2017-01-19     김신기       오후   2:24                      재미 읽씹하냐 ㅜㅜ
# 26     2017-01-19     김재민       오후   2:24                            아니기달
# 27     2017-01-19     김재민       오후   2:25                          나아직못삿어
# 28     2017-01-19     김재민       오후   2:25                          런던즐겨찾기
# 29     2017-01-19     김재민       오후   2:25                          거기서진행중
# ...           ...     ...      ...    ...                             ...
# 149178 2020-02-27    곽종현🎗       오전   1:43                           잠잠해지면
# 149179 2020-02-27    곽종현🎗       오전   1:43                        부산 내려갈낀데
# 149180 2020-02-27     김성화       오전   1:43                        우정테스트 탈락
# 149181 2020-02-27    곽종현🎗       오전   1:43                          그때 들릴게
# 149182 2020-02-27     김성화       오전   1:43                            이모티콘
# 149183 2020-02-27     김성화       오전   1:43                               뀨
# 149184 2020-02-27    곽종현🎗       오전   1:43                      아니 개심심한가보네
# 149185 2020-02-27     김성화       오전   1:43                              ㅇㅇ
# 149186 2020-02-27     김성화       오전   1:44                심심해서 잘라고 딱 각잡았는데
# 149187 2020-02-27     김성화       오전   1:44                       카톡오더라 너가❤
# 149188 2020-02-27    곽종현🎗       오전   1:45                          좀 자그래이
# 149189 2020-02-27     김성화       오전   1:46                       쫓아내는 느낌이노
# 149190 2020-02-27    곽종현🎗       오전   1:46                            ㅋㅋㅋㅋ
# 149191 2020-02-27     김성화       오전   1:46                            이모티콘
# 149192 2020-02-27    곽종현🎗       오전   1:46                             아니노
# 149193 2020-02-27    곽종현🎗       오전   1:46                         눈치존나빠르네
# 149194 2020-02-27     김성화       오전   1:46                        이모티콘 사줄까
# 149195 2020-02-27    곽종현🎗       오전   1:46                              아니
# 149196 2020-02-27    곽종현🎗       오전   1:46                               어
# 149197 2020-02-27    곽종현🎗       오전   1:46                            이모티콘
# 149198 2020-02-27    곽종현🎗       오전   1:46                          나도 좀 도
# 149199 2020-02-27     김성화       오전   1:46                     내가 골라서 줘도되나
# 149200 2020-02-27     김성화       오전   1:46                            이모티콘
# 149201 2020-02-27    곽종현🎗       오전   1:46                            ㅎㅎㅎㅎ
# 149202 2020-02-27    곽종현🎗       오전   1:46                       엄한데 돈쓰지말고
# 149203 2020-02-27    곽종현🎗       오전   1:47                            퍼뜩자라
# 149204 2020-02-27     김성화       오전   1:47                            이모티콘
# 149205 2020-02-27     김성화       오전   1:47                            이모티콘
# 149206 2020-02-27     김성화       오전   1:47                            이모티콘
# 149207 2020-02-27     김성화       오전   1:47                            이모티콘
#
#         year month day   weekday    24time  \
# 0       2017    01  19  Thursday  02:16:00
# 1       2017    01  19  Thursday  02:16:00
# 2       2017    01  19  Thursday  02:19:00
# 3       2017    01  19  Thursday  02:19:00
# 4       2017    01  19  Thursday  02:19:00
# 5       2017    01  19  Thursday  02:21:00
# 6       2017    01  19  Thursday  02:21:00
# 7       2017    01  19  Thursday  02:21:00
# 8       2017    01  19  Thursday  02:21:00
# 9       2017    01  19  Thursday  02:22:00
# 10      2017    01  19  Thursday  02:26:00
# 11      2017    01  19  Thursday  02:26:00
# 12      2017    01  19  Thursday  02:28:00
# 13      2017    01  19  Thursday  02:29:00
# 14      2017    01  19  Thursday  02:29:00
# 15      2017    01  19  Thursday  02:35:00
# 16      2017    01  19  Thursday  02:35:00
# 17      2017    01  19  Thursday  02:35:00
# 18      2017    01  19  Thursday  02:36:00
# 19      2017    01  19  Thursday  02:36:00
# 20      2017    01  19  Thursday  02:37:00
# 21      2017    01  19  Thursday  02:38:00
# 22      2017    01  19  Thursday  02:40:00
# 23      2017    01  19  Thursday  11:28:00
# 24      2017    01  19  Thursday  13:13:00
# 25      2017    01  19  Thursday  14:24:00
# 26      2017    01  19  Thursday  14:24:00
# 27      2017    01  19  Thursday  14:25:00
# 28      2017    01  19  Thursday  14:25:00
# 29      2017    01  19  Thursday  14:25:00
# ...      ...   ...  ..       ...       ...
# 149178  2020    02  27  Thursday  01:43:00
# 149179  2020    02  27  Thursday  01:43:00
# 149180  2020    02  27  Thursday  01:43:00
# 149181  2020    02  27  Thursday  01:43:00
# 149182  2020    02  27  Thursday  01:43:00
# 149183  2020    02  27  Thursday  01:43:00
# 149184  2020    02  27  Thursday  01:43:00
# 149185  2020    02  27  Thursday  01:43:00
# 149186  2020    02  27  Thursday  01:44:00
# 149187  2020    02  27  Thursday  01:44:00
# 149188  2020    02  27  Thursday  01:45:00
# 149189  2020    02  27  Thursday  01:46:00
# 149190  2020    02  27  Thursday  01:46:00
# 149191  2020    02  27  Thursday  01:46:00
# 149192  2020    02  27  Thursday  01:46:00
# 149193  2020    02  27  Thursday  01:46:00
# 149194  2020    02  27  Thursday  01:46:00
# 149195  2020    02  27  Thursday  01:46:00
# 149196  2020    02  27  Thursday  01:46:00
# 149197  2020    02  27  Thursday  01:46:00
# 149198  2020    02  27  Thursday  01:46:00
# 149199  2020    02  27  Thursday  01:46:00
# 149200  2020    02  27  Thursday  01:46:00
# 149201  2020    02  27  Thursday  01:46:00
# 149202  2020    02  27  Thursday  01:46:00
# 149203  2020    02  27  Thursday  01:47:00
# 149204  2020    02  27  Thursday  01:47:00
# 149205  2020    02  27  Thursday  01:47:00
# 149206  2020    02  27  Thursday  01:47:00
# 149207  2020    02  27  Thursday  01:47:00
#
#                               ...                          quarter  \
# 0                             ...                               1q
# 1                             ...                               1q
# 2                             ...                               1q
# 3                             ...                               1q
# 4                             ...                               1q
# 5                             ...                               1q
# 6                             ...                               1q
# 7                             ...                               1q
# 8                             ...                               1q
# 9                             ...                               1q
# 10                            ...                               1q
# 11                            ...                               1q
# 12                            ...                               1q
# 13                            ...                               1q
# 14                            ...                               1q
# 15                            ...                               1q
# 16                            ...                               1q
# 17                            ...                               1q
# 18                            ...                               1q
# 19                            ...                               1q
# 20                            ...                               1q
# 21                            ...                               1q
# 22                            ...                               1q
# 23                            ...                               1q
# 24                            ...                               1q
# 25                            ...                               1q
# 26                            ...                               1q
# 27                            ...                               1q
# 28                            ...                               1q
# 29                            ...                               1q
# ...                           ...                              ...
# 149178                        ...                               1q
# 149179                        ...                               1q
# 149180                        ...                               1q
# 149181                        ...                               1q
# 149182                        ...                               1q
# 149183                        ...                               1q
# 149184                        ...                               1q
# 149185                        ...                               1q
# 149186                        ...                               1q
# 149187                        ...                               1q
# 149188                        ...                               1q
# 149189                        ...                               1q
# 149190                        ...                               1q
# 149191                        ...                               1q
# 149192                        ...                               1q
# 149193                        ...                               1q
# 149194                        ...                               1q
# 149195                        ...                               1q
# 149196                        ...                               1q
# 149197                        ...                               1q
# 149198                        ...                               1q
# 149199                        ...                               1q
# 149200                        ...                               1q
# 149201                        ...                               1q
# 149202                        ...                               1q
# 149203                        ...                               1q
# 149204                        ...                               1q
# 149205                        ...                               1q
# 149206                        ...                               1q
# 149207                        ...                               1q
#
#                   Datetime    delta is_indifferent  \
# 0      2017-01-19 02:16:00 00:00:00          False
# 1      2017-01-19 02:16:00 00:03:00          False
# 2      2017-01-19 02:19:00 00:00:00          False
# 3      2017-01-19 02:19:00 00:00:00          False
# 4      2017-01-19 02:19:00 00:02:00          False
# 5      2017-01-19 02:21:00 00:00:00          False
# 6      2017-01-19 02:21:00 00:00:00          False
# 7      2017-01-19 02:21:00 00:00:00          False
# 8      2017-01-19 02:21:00 00:01:00          False
# 9      2017-01-19 02:22:00 00:04:00          False
# 10     2017-01-19 02:26:00 00:00:00          False
# 11     2017-01-19 02:26:00 00:02:00          False
# 12     2017-01-19 02:28:00 00:01:00          False
# 13     2017-01-19 02:29:00 00:00:00          False
# 14     2017-01-19 02:29:00 00:06:00          False
# 15     2017-01-19 02:35:00 00:00:00          False
# 16     2017-01-19 02:35:00 00:00:00          False
# 17     2017-01-19 02:35:00 00:01:00          False
# 18     2017-01-19 02:36:00 00:00:00          False
# 19     2017-01-19 02:36:00 00:01:00          False
# 20     2017-01-19 02:37:00 00:01:00          False
# 21     2017-01-19 02:38:00 00:02:00          False
# 22     2017-01-19 02:40:00 08:48:00          False
# 23     2017-01-19 11:28:00 01:45:00          False
# 24     2017-01-19 13:13:00 01:11:00          False
# 25     2017-01-19 14:24:00 00:00:00          False
# 26     2017-01-19 14:24:00 00:01:00          False
# 27     2017-01-19 14:25:00 00:00:00          False
# 28     2017-01-19 14:25:00 00:00:00          False
# 29     2017-01-19 14:25:00 00:00:00          False
# ...                    ...      ...            ...
# 149178 2020-02-27 01:43:00 00:00:00          False
# 149179 2020-02-27 01:43:00 00:00:00          False
# 149180 2020-02-27 01:43:00 00:00:00          False
# 149181 2020-02-27 01:43:00 00:00:00          False
# 149182 2020-02-27 01:43:00 00:00:00          False
# 149183 2020-02-27 01:43:00 00:00:00          False
# 149184 2020-02-27 01:43:00 00:00:00          False
# 149185 2020-02-27 01:43:00 00:01:00          False
# 149186 2020-02-27 01:44:00 00:00:00          False
# 149187 2020-02-27 01:44:00 00:01:00          False
# 149188 2020-02-27 01:45:00 00:01:00          False
# 149189 2020-02-27 01:46:00 00:00:00          False
# 149190 2020-02-27 01:46:00 00:00:00          False
# 149191 2020-02-27 01:46:00 00:00:00          False
# 149192 2020-02-27 01:46:00 00:00:00          False
# 149193 2020-02-27 01:46:00 00:00:00          False
# 149194 2020-02-27 01:46:00 00:00:00          False
# 149195 2020-02-27 01:46:00 00:00:00          False
# 149196 2020-02-27 01:46:00 00:00:00          False
# 149197 2020-02-27 01:46:00 00:00:00          False
# 149198 2020-02-27 01:46:00 00:00:00          False
# 149199 2020-02-27 01:46:00 00:00:00          False
# 149200 2020-02-27 01:46:00 00:00:00          False
# 149201 2020-02-27 01:46:00 00:00:00          False
# 149202 2020-02-27 01:46:00 00:01:00          False
# 149203 2020-02-27 01:47:00 00:00:00          False
# 149204 2020-02-27 01:47:00 00:00:00          False
# 149205 2020-02-27 01:47:00 00:00:00          False
# 149206 2020-02-27 01:47:00 00:00:00          False
# 149207 2020-02-27 01:47:00 00:00:00          False
#
#                                 new                         nnew  \
# 0                        오 팁 이만냥 받음                   오 팁 이만냥 받음
# 1                       재민 그동네 좀 좋네                     그동네 좀 좋네
# 2                                 오                            오
# 3                       난 카지노 3만원잃음                  난 카지노 3만원잃음
# 4
# 5                                븅신                           븅신
# 6
# 7                    여기 한심하게돈많은놈들많더               여기 한심하게돈많은놈들많더
# 8                               개부럽                          개부럽
# 9                      그새끼들 연락처받아놔라                 그새끼들 연락처받아놔라
# 10
# 11                        근데좀무섭게생겻다                    근데좀무섭게생겻다
# 12      그런애들 아빠가 콤마 틀라이언트 계약해주실수도있다  그런애들 아빠가 콤마 틀라이언트 계약해주실수도있다
# 13                                오                            오
# 14                           상하이 선화                       상하이 선화
# 15                         ㅣ번 여름방학땐                     ㅣ번 여름방학땐
# 16            콤마 팀들 ㅗ모전이고 나발이고 집어치고        콤마 팀들 ㅗ모전이고 나발이고 집어치고
# 17                         중국어공부시켜라                     중국어공부시켜라
# 18
# 19                             해외진출                         해외진출
# 20                       아 알바 마치고싶다                   아 알바 마치고싶다
# 21                              마쳐라                          마쳐라
# 22                           피고내피고내                       피고내피고내
# 23       재민아 토트넘 경기 어떤 사이트 통해서 예매햇냐   재민아 토트넘 경기 어떤 사이트 통해서 예매햇냐
# 24                               쿠팡                           쿠팡
# 25                         재미 읽씹하냐                         읽씹하냐
# 26                             아니기달                         아니기달
# 27                           나아직못삿어                       나아직못삿어
# 28                           런던즐겨찾기                       런던즐겨찾기
# 29                           거기서진행중                       거기서진행중
# ...                             ...                          ...
# 149178                        잠잠해지면                        잠잠해지면
# 149179                     부산 내려갈낀데                     부산 내려갈낀데
# 149180                     우정테스트 탈락                     우정테스트 탈락
# 149181                       그때 들릴게                       그때 들릴게
# 149182                         이모티콘                         이모티콘
# 149183                            뀨                            뀨
# 149184                   아니 개심심한가보네                   아니 개심심한가보네
# 149185
# 149186             심심해서 잘라고 딱 각잡았는데             심심해서 잘라고 딱 각잡았는데
# 149187                    카톡오더라 너가❤                    카톡오더라 너가❤
# 149188                       좀 자그래이                       좀 자그래이
# 149189                    쫓아내는 느낌이노                    쫓아내는 느낌이노
# 149190
# 149191                         이모티콘                         이모티콘
# 149192                          아니노                          아니노
# 149193                      눈치존나빠르네                      눈치존나빠르네
# 149194                     이모티콘 사줄까                     이모티콘 사줄까
# 149195                           아니                           아니
# 149196                            어                            어
# 149197                         이모티콘                         이모티콘
# 149198                       나도 좀 도                          좀 도
# 149199                  내가 골라서 줘도되나                  내가 골라서 줘도되나
# 149200                         이모티콘                         이모티콘
# 149201
# 149202                    엄한데 돈쓰지말고                    엄한데 돈쓰지말고
# 149203                         퍼뜩자라                         퍼뜩자라
# 149204                         이모티콘                         이모티콘
# 149205                         이모티콘                         이모티콘
# 149206                         이모티콘                         이모티콘
# 149207                         이모티콘                         이모티콘
#
#                              nouns  \
# 0                       [오, 팁, 이만]
# 1                          [동네, 좀]
# 2                              [오]
# 3                         [난, 카지노]
# 4                               []
# 5                             [븅신]
# 6                               []
# 7                       [여기, 돈, 놈]
# 8                              [개]
# 9                        [새끼, 연락처]
# 10                              []
# 11                         [좀, 생겻]
# 12      [애, 아빠, 콤마, 틀, 라이언, 트, 계약]
# 13                             [오]
# 14                       [상하이, 선화]
# 15                    [번, 여름방학, 땐]
# 16                 [콤마, 팀, 전이, 나발]
# 17                       [중국어, 공부]
# 18                              []
# 19                          [해외진출]
# 20                        [알바, 마치]
# 21                              []
# 22                        [피고, 피고]
# 23       [재민, 토트넘, 경기, 사이트, 통해, 햇]
# 24                            [쿠팡]
# 25                              []
# 26                             [달]
# 27                           [직못삿]
# 28                      [런던, 즐겨찾기]
# 29                       [거기, 진행중]
# ...                            ...
# 149178                          []
# 149179                        [부산]
# 149180               [우정, 테스트, 탈락]
# 149181                        [그때]
# 149182                      [이모티콘]
# 149183                         [뀨]
# 149184                        [개심]
# 149185                          []
# 149186                         [각]
# 149187                     [카톡, 너]
# 149188                      [좀, 자]
# 149189                    [느낌, 이노]
# 149190                          []
# 149191                      [이모티콘]
# 149192                          []
# 149193                    [눈치, 존나]
# 149194                      [이모티콘]
# 149195                          []
# 149196                          []
# 149197                      [이모티콘]
# 149198                      [좀, 도]
# 149199                      [내, 골]
# 149200                      [이모티콘]
# 149201                          []
# 149202                    [엄한데, 돈]
# 149203                    [퍼뜩, 자라]
# 149204                      [이모티콘]
# 149205                      [이모티콘]
# 149206                      [이모티콘]
# 149207                      [이모티콘]
#
#                                                  morphs  \
# 0                                     [오, 팁, 이만, 냥, 받음]
# 1                                        [그, 동네, 좀, 좋네]
# 2                                                   [오]
# 3                                     [난, 카지노, 3만원, 잃음]
# 4                                                    []
# 5                                                  [븅신]
# 6                                                    []
# 7                           [여기, 한심하게, 돈, 많은, 놈, 들, 많더]
# 8                                               [개, 부럽]
# 9                               [그, 새끼, 들, 연락처, 받아, 놔라]
# 10                                                   []
# 11                                  [근데, 좀, 무섭게, 생겻, 다]
# 12      [그런, 애, 들, 아빠, 가, 콤마, 틀, 라이언, 트, 계약, 해주실수도, 있다]
# 13                                                  [오]
# 14                                            [상하이, 선화]
# 15                                      [ㅣ, 번, 여름방학, 땐]
# 16                [콤마, 팀, 들, ㅗ, 모, 전이, 고, 나발, 이고, 집어치고]
# 17                                       [중국어, 공부, 시켜라]
# 18                                                   []
# 19                                               [해외진출]
# 20                                   [아, 알바, 마치, 고, 싶다]
# 21                                                [마쳐라]
# 22                                       [피고, 내, 피고, 내]
# 23         [재민, 아, 토트넘, 경기, 어떤, 사이트, 통해, 서, 예, 매, 햇, 냐]
# 24                                                 [쿠팡]
# 25                                             [읽, 씹하냐]
# 26                                             [아니기, 달]
# 27                                         [나아, 직못삿, 어]
# 28                                           [런던, 즐겨찾기]
# 29                                         [거기, 서, 진행중]
# ...                                                 ...
# 149178                                          [잠잠해지면]
# 149179                                    [부산, 내려갈, 낀데]
# 149180                                    [우정, 테스트, 탈락]
# 149181                                        [그때, 들릴게]
# 149182                                           [이모티콘]
# 149183                                              [뀨]
# 149184                                [아니, 개심, 심한, 가보네]
# 149185                                               []
# 149186                          [심심해서, 잘라고, 딱, 각, 잡았는데]
# 149187                               [카톡, 오더라, 너, 가, ❤]
# 149188                                      [좀, 자, 그래이]
# 149189                                   [쫓아내는, 느낌, 이노]
# 149190                                               []
# 149191                                           [이모티콘]
# 149192                                            [아니노]
# 149193                                    [눈치, 존나, 빠르네]
# 149194                                      [이모티콘, 사줄까]
# 149195                                             [아니]
# 149196                                              [어]
# 149197                                           [이모티콘]
# 149198                                           [좀, 도]
# 149199                            [내, 가, 골, 라서, 줘도, 되나]
# 149200                                           [이모티콘]
# 149201                                               []
# 149202                                   [엄한데, 돈, 쓰지말고]
# 149203                                         [퍼뜩, 자라]
# 149204                                           [이모티콘]
# 149205                                           [이모티콘]
# 149206                                           [이모티콘]
# 149207                                           [이모티콘]
#
#                                                       pos  \
# 0       [(오, Noun), (팁, Noun), (이만, Noun), (냥, Josa), ...
# 1       [(그, Determiner), (동네, Noun), (좀, Noun), (좋네, ...
# 2                                             [(오, Noun)]
# 3       [(난, Noun), (카지노, Noun), (3만원, Number), (잃음, F...
# 4                                                      []
# 5                                            [(븅신, Noun)]
# 6                                                      []
# 7       [(여기, Noun), (한심하게, Adjective), (돈, Noun), (많은...
# 8                            [(개, Noun), (부럽, Adjective)]
# 9       [(그, Determiner), (새끼, Noun), (들, Suffix), (연락...
# 10                                                     []
# 11      [(근데, Adverb), (좀, Noun), (무섭게, Adjective), (생...
# 12      [(그런, Modifier), (애, Noun), (들, Suffix), (아빠, ...
# 13                                            [(오, Noun)]
# 14                              [(상하이, Noun), (선화, Noun)]
# 15      [(ㅣ, KoreanParticle), (번, Noun), (여름방학, Noun),...
# 16      [(콤마, Noun), (팀, Noun), (들, Suffix), (ㅗ, Korea...
# 17                 [(중국어, Noun), (공부, Noun), (시켜라, Verb)]
# 18                                                     []
# 19                                         [(해외진출, Noun)]
# 20      [(아, Exclamation), (알바, Noun), (마치, Noun), (고,...
# 21                                          [(마쳐라, Verb)]
# 22      [(피고, Noun), (내, Determiner), (피고, Noun), (내, ...
# 23      [(재민, Noun), (아, Josa), (토트넘, Noun), (경기, Noun...
# 24                                           [(쿠팡, Noun)]
# 25                               [(읽, Verb), (씹하냐, Verb)]
# 26                          [(아니기, Adjective), (달, Noun)]
# 27               [(나아, Adverb), (직못삿, Noun), (어, Suffix)]
# 28                             [(런던, Noun), (즐겨찾기, Noun)]
# 29                   [(거기, Noun), (서, Josa), (진행중, Noun)]
# ...                                                   ...
# 149178                               [(잠잠해지면, Adjective)]
# 149179              [(부산, Noun), (내려갈, Verb), (낀데, Verb)]
# 149180              [(우정, Noun), (테스트, Noun), (탈락, Noun)]
# 149181                          [(그때, Noun), (들릴게, Verb)]
# 149182                                     [(이모티콘, Noun)]
# 149183                                        [(뀨, Noun)]
# 149184  [(아니, Adjective), (개심, Noun), (심한, Adjective),...
# 149185                                                 []
# 149186  [(심심해서, Adjective), (잘라고, Verb), (딱, Adverb), ...
# 149187  [(카톡, Noun), (오더라, Verb), (너, Noun), (가, Josa)...
# 149188           [(좀, Noun), (자, Noun), (그래이, Adjective)]
# 149189             [(쫓아내는, Verb), (느낌, Noun), (이노, Noun)]
# 149190                                                 []
# 149191                                     [(이모티콘, Noun)]
# 149192                                 [(아니노, Adjective)]
# 149193         [(눈치, Noun), (존나, Noun), (빠르네, Adjective)]
# 149194                        [(이모티콘, Noun), (사줄까, Verb)]
# 149195                                  [(아니, Adjective)]
# 149196                                        [(어, Eomi)]
# 149197                                     [(이모티콘, Noun)]
# 149198                             [(좀, Noun), (도, Noun)]
# 149199  [(내, Noun), (가, Josa), (골, Noun), (라서, Josa), ...
# 149200                                     [(이모티콘, Noun)]
# 149201                                                 []
# 149202             [(엄한데, Noun), (돈, Noun), (쓰지말고, Verb)]
# 149203                           [(퍼뜩, Noun), (자라, Noun)]
# 149204                                     [(이모티콘, Noun)]
# 149205                                     [(이모티콘, Noun)]
# 149206                                     [(이모티콘, Noun)]
# 149207                                     [(이모티콘, Noun)]
#
#                                                  dic_verb
# 0       {'오': 'Noun', '팁': 'Noun', '이만': 'Noun', '냥': ...
# 1       {'그': 'Determiner', '동네': 'Noun', '좀': 'Noun',...
# 2                                           {'오': 'Noun'}
# 3       {'난': 'Noun', '카지노': 'Noun', '3만원': 'Number', ...
# 4                                                      {}
# 5                                          {'븅신': 'Noun'}
# 6                                                      {}
# 7       {'여기': 'Noun', '한심하게': 'Adjective', '돈': 'Noun...
# 8                        {'개': 'Noun', '부럽': 'Adjective'}
# 9       {'그': 'Determiner', '새끼': 'Noun', '들': 'Suffix...
# 10                                                     {}
# 11      {'근데': 'Adverb', '좀': 'Noun', '무섭게': 'Adjectiv...
# 12      {'그런': 'Modifier', '애': 'Noun', '들': 'Suffix',...
# 13                                          {'오': 'Noun'}
# 14                          {'상하이': 'Noun', '선화': 'Noun'}
# 15      {'ㅣ': 'KoreanParticle', '번': 'Noun', '여름방학': '...
# 16      {'콤마': 'Noun', '팀': 'Noun', '들': 'Suffix', 'ㅗ'...
# 17           {'중국어': 'Noun', '공부': 'Noun', '시켜라': 'Verb'}
# 18                                                     {}
# 19                                       {'해외진출': 'Noun'}
# 20      {'아': 'Exclamation', '알바': 'Noun', '마치': 'Noun...
# 21                                        {'마쳐라': 'Verb'}
# 22                      {'피고': 'Noun', '내': 'Determiner'}
# 23      {'재민': 'Noun', '아': 'Josa', '토트넘': 'Noun', '경기...
# 24                                         {'쿠팡': 'Noun'}
# 25                           {'읽': 'Verb', '씹하냐': 'Verb'}
# 26                      {'아니기': 'Adjective', '달': 'Noun'}
# 27         {'나아': 'Adverb', '직못삿': 'Noun', '어': 'Suffix'}
# 28                         {'런던': 'Noun', '즐겨찾기': 'Noun'}
# 29             {'거기': 'Noun', '서': 'Josa', '진행중': 'Noun'}
# ...                                                   ...
# 149178                             {'잠잠해지면': 'Adjective'}
# 149179        {'부산': 'Noun', '내려갈': 'Verb', '낀데': 'Verb'}
# 149180        {'우정': 'Noun', '테스트': 'Noun', '탈락': 'Noun'}
# 149181                      {'그때': 'Noun', '들릴게': 'Verb'}
# 149182                                   {'이모티콘': 'Noun'}
# 149183                                      {'뀨': 'Noun'}
# 149184  {'아니': 'Adjective', '개심': 'Noun', '심한': 'Adjec...
# 149185                                                 {}
# 149186  {'심심해서': 'Adjective', '잘라고': 'Verb', '딱': 'Adv...
# 149187  {'카톡': 'Noun', '오더라': 'Verb', '너': 'Noun', '가'...
# 149188     {'좀': 'Noun', '자': 'Noun', '그래이': 'Adjective'}
# 149189       {'쫓아내는': 'Verb', '느낌': 'Noun', '이노': 'Noun'}
# 149190                                                 {}
# 149191                                   {'이모티콘': 'Noun'}
# 149192                               {'아니노': 'Adjective'}
# 149193   {'눈치': 'Noun', '존나': 'Noun', '빠르네': 'Adjective'}
# 149194                    {'이모티콘': 'Noun', '사줄까': 'Verb'}
# 149195                                {'아니': 'Adjective'}
# 149196                                      {'어': 'Eomi'}
# 149197                                   {'이모티콘': 'Noun'}
# 149198                         {'좀': 'Noun', '도': 'Noun'}
# 149199  {'내': 'Noun', '가': 'Josa', '골': 'Noun', '라서': ...
# 149200                                   {'이모티콘': 'Noun'}
# 149201                                                 {}
# 149202       {'엄한데': 'Noun', '돈': 'Noun', '쓰지말고': 'Verb'}
# 149203                       {'퍼뜩': 'Noun', '자라': 'Noun'}
# 149204                                   {'이모티콘': 'Noun'}
# 149205                                   {'이모티콘': 'Noun'}
# 149206                                   {'이모티콘': 'Noun'}
# 149207                                   {'이모티콘': 'Noun'}
#
# [149208 rows x 23 columns]

# %%
verb_2 = []

for i in range(len(dict_verb)):
    verb_3 = [str(key) for (key, value) in dict_verb[i].items() if value == 'Verb']
    verb_2.append(verb_3)

df['verb'] =verb_2

# %%
df.head()
# Out:
#         Date Speaker timetype  time     contents  year month day   weekday  \
# 0 2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음  2017    01  19  Thursday
# 1 2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네  2017    01  19  Thursday
# 2 2017-01-19     김재민       오전  2:19            오  2017    01  19  Thursday
# 3 2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음  2017    01  19  Thursday
# 4 2017-01-19     김재민       오전  2:19          ㅋㅋㅋ  2017    01  19  Thursday
#
#      24time  ...             Datetime    delta is_indifferent          new  \
# 0  02:16:00  ...  2017-01-19 02:16:00 00:00:00          False   오 팁 이만냥 받음
# 1  02:16:00  ...  2017-01-19 02:16:00 00:03:00          False  재민 그동네 좀 좋네
# 2  02:19:00  ...  2017-01-19 02:19:00 00:00:00          False            오
# 3  02:19:00  ...  2017-01-19 02:19:00 00:00:00          False  난 카지노 3만원잃음
# 4  02:19:00  ...  2017-01-19 02:19:00 00:02:00          False
#
#           nnew       nouns             morphs  \
# 0   오 팁 이만냥 받음  [오, 팁, 이만]  [오, 팁, 이만, 냥, 받음]
# 1     그동네 좀 좋네     [동네, 좀]     [그, 동네, 좀, 좋네]
# 2            오         [오]                [오]
# 3  난 카지노 3만원잃음    [난, 카지노]  [난, 카지노, 3만원, 잃음]
# 4                       []                 []
#
#                                                  pos  \
# 0  [(오, Noun), (팁, Noun), (이만, Noun), (냥, Josa), ...
# 1  [(그, Determiner), (동네, Noun), (좀, Noun), (좋네, ...
# 2                                        [(오, Noun)]
# 3  [(난, Noun), (카지노, Noun), (3만원, Number), (잃음, F...
# 4                                                 []
#
#                                             dic_verb  verb
# 0  {'오': 'Noun', '팁': 'Noun', '이만': 'Noun', '냥': ...  [받음]
# 1  {'그': 'Determiner', '동네': 'Noun', '좀': 'Noun',...    []
# 2                                      {'오': 'Noun'}    []
# 3  {'난': 'Noun', '카지노': 'Noun', '3만원': 'Number', ...    []
# 4                                                 {}    []
#
# [5 rows x 24 columns]

# %%
df['sentence'] = df['nouns'] + df['verb']
df.head()
# Out:
#         Date Speaker timetype  time     contents  year month day   weekday  \
# 0 2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음  2017    01  19  Thursday
# 1 2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네  2017    01  19  Thursday
# 2 2017-01-19     김재민       오전  2:19            오  2017    01  19  Thursday
# 3 2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음  2017    01  19  Thursday
# 4 2017-01-19     김재민       오전  2:19          ㅋㅋㅋ  2017    01  19  Thursday
#
#      24time       ...          delta is_indifferent          new         nnew  \
# 0  02:16:00       ...       00:00:00          False   오 팁 이만냥 받음   오 팁 이만냥 받음
# 1  02:16:00       ...       00:03:00          False  재민 그동네 좀 좋네     그동네 좀 좋네
# 2  02:19:00       ...       00:00:00          False            오            오
# 3  02:19:00       ...       00:00:00          False  난 카지노 3만원잃음  난 카지노 3만원잃음
# 4  02:19:00       ...       00:02:00          False
#
#         nouns             morphs  \
# 0  [오, 팁, 이만]  [오, 팁, 이만, 냥, 받음]
# 1     [동네, 좀]     [그, 동네, 좀, 좋네]
# 2         [오]                [오]
# 3    [난, 카지노]  [난, 카지노, 3만원, 잃음]
# 4          []                 []
#
#                                                  pos  \
# 0  [(오, Noun), (팁, Noun), (이만, Noun), (냥, Josa), ...
# 1  [(그, Determiner), (동네, Noun), (좀, Noun), (좋네, ...
# 2                                        [(오, Noun)]
# 3  [(난, Noun), (카지노, Noun), (3만원, Number), (잃음, F...
# 4                                                 []
#
#                                             dic_verb  verb        sentence
# 0  {'오': 'Noun', '팁': 'Noun', '이만': 'Noun', '냥': ...  [받음]  [오, 팁, 이만, 받음]
# 1  {'그': 'Determiner', '동네': 'Noun', '좀': 'Noun',...    []         [동네, 좀]
# 2                                      {'오': 'Noun'}    []             [오]
# 3  {'난': 'Noun', '카지노': 'Noun', '3만원': 'Number', ...    []        [난, 카지노]
# 4                                                 {}    []              []
#
# [5 rows x 25 columns]

# %%
tokenized_doc = df['sentence']
detokenized_doc = []

for i in range(len(df)):
    t = ' '.join(tokenized_doc[i])
    detokenized_doc.append(t)
df['headline_text'] = detokenized_doc
# 다시 text['headline_text'] 에 저장
df.head()
# Out:
#         Date Speaker timetype  time     contents  year month day   weekday  \
# 0 2017-01-19     김성화       오전  2:16   오 팁 이만냥 받음  2017    01  19  Thursday
# 1 2017-01-19     김성화       오전  2:16  재민 그동네 좀 좋네  2017    01  19  Thursday
# 2 2017-01-19     김재민       오전  2:19            오  2017    01  19  Thursday
# 3 2017-01-19     김재민       오전  2:19  난 카지노 3만원잃음  2017    01  19  Thursday
# 4 2017-01-19     김재민       오전  2:19          ㅋㅋㅋ  2017    01  19  Thursday
#
#      24time      ...       is_indifferent          new         nnew  \
# 0  02:16:00      ...                False   오 팁 이만냥 받음   오 팁 이만냥 받음
# 1  02:16:00      ...                False  재민 그동네 좀 좋네     그동네 좀 좋네
# 2  02:19:00      ...                False            오            오
# 3  02:19:00      ...                False  난 카지노 3만원잃음  난 카지노 3만원잃음
# 4  02:19:00      ...                False
#
#         nouns             morphs  \
# 0  [오, 팁, 이만]  [오, 팁, 이만, 냥, 받음]
# 1     [동네, 좀]     [그, 동네, 좀, 좋네]
# 2         [오]                [오]
# 3    [난, 카지노]  [난, 카지노, 3만원, 잃음]
# 4          []                 []
#
#                                                  pos  \
# 0  [(오, Noun), (팁, Noun), (이만, Noun), (냥, Josa), ...
# 1  [(그, Determiner), (동네, Noun), (좀, Noun), (좋네, ...
# 2                                        [(오, Noun)]
# 3  [(난, Noun), (카지노, Noun), (3만원, Number), (잃음, F...
# 4                                                 []
#
#                                             dic_verb  verb        sentence  \
# 0  {'오': 'Noun', '팁': 'Noun', '이만': 'Noun', '냥': ...  [받음]  [오, 팁, 이만, 받음]
# 1  {'그': 'Determiner', '동네': 'Noun', '좀': 'Noun',...    []         [동네, 좀]
# 2                                      {'오': 'Noun'}    []             [오]
# 3  {'난': 'Noun', '카지노': 'Noun', '3만원': 'Number', ...    []        [난, 카지노]
# 4                                                 {}    []              []
#
#   headline_text
# 0     오 팁 이만 받음
# 1          동네 좀
# 2             오
# 3         난 카지노
# 4
#
# [5 rows x 26 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english',max_features=1000)
X = vectorizer.fit_transform(df['headline_text'])
X.shape
# Out:
# (149208, 1000)

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda_model = LatentDirichletAllocation(n_components=10, learning_method='online', random_state=777, max_iter=1)
lda_top = lda_model.fit_transform(X)

# %%
terms = vectorizer.get_feature_names() 
# 단어 집합. 1,000개의 단어가 저장되어있음.
df = []
def get_topics(components, feature_names, n=10):
    for idx, topic in enumerate(components):
        df.append([(feature_names[i]) for i in topic.argsort()[:-n -1:-1]])
get_topics(lda_model.components_, terms)

# %%
df = pd.DataFrame(df)
df.columns = ['topic1','topic2','topic3','topic4','topic5','topic6','topic7','topic8'
              ,'topic9','topic10']
df.reset_index(drop=True)
# Out:
#   topic1 topic2 topic3 topic4 topic5 topic6 topic7 topic8 topic9 topic10
# 0     이노     추천     미안     소리     운동     학원     여자     영어     먹고      머리
# 1     카페     거기     주식     고생     할게     해라     보고     보면     출근      아침
# 2     하노     사람     하나     시간     느낌     경찰     한번     렁화     리얼      여행
# 3     종현     친구     우리     무슨     처음     자기     는데     봐라     이제      하루
# 4     진짜     여기     혜원     원래     대구     얼마     방금    인스타     해야      때문
# 5   이모티콘     요즘     누구     하자     노래     한국     지금     이름     들어     하는거
# 6     사진     검색     머민     공부     요미     되나     교수     전화    봤는데      병원
# 7     오늘     하는     해서     정도     신세     학교     저녁     이번     문제      시작
# 8     신기    이야기     어디     바로     하고     성화     내일     해도     다시      언제
# 9     그냥     생각     하면     어제     재민     한다     했다    했는데     요요      그때
